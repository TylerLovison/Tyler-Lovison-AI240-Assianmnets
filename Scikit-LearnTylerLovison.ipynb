# %% [markdown]
# ## Edited on 10/2/2025 - 10/5/2025
# Tyler Lovison
# AI240

# %% [markdown]
# ## Exercise 1

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\tmlov\anaconda3\lib\site-packages (1.26.4)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\tmlov\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\tmlov\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\tmlov\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tmlov\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tmlov\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.5.1
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: C:\Users\tmlov\anaconda3\Lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: imbalanced-learn

# %% [markdown]
# ## Exercise 2

# %%
import numpy as np
import pandas as pd

import sklearn
from sklearn import datasets

# %% [markdown]
# ## Exercise 3

# %%
iris = datasets.load_iris()

# dataset includes:
# Feature matrix (X)
# Response vector (y)
# Feature names
# Target names

# %% [markdown]
# ## Exercise 4

# %%
from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names

print("Feature names:", feature_names)
print("Target names:", target_names)
print("\nFirst 10 rows of X:\n", X[:10])
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names: ['setosa' 'versicolor' 'virginica']
#
# First 10 rows of X:
#  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]]

# %% [markdown]
# ## Exercise 5

# %%
from sklearn.model_selection import train_test_split

# Split data into training (80%) and testing (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (120, 4)
# X_test shape: (30, 4)
# y_train shape: (120,)
# y_test shape: (30,)

# %% [markdown]
# ## Exercise 6

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# Initialize KNN with k = 5
classifier_knn = KNeighborsClassifier(n_neighbors=5)

# Train the model
classifier_knn.fit(X_train, y_train)

# Predict using test data
y_pred = classifier_knn.predict(X_test)

# Evaluate model accuracy
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
